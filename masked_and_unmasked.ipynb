# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIJITH54/mask-detection-rf/blob/main/masked_and_unmasked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from skimage.transform import resize
from skimage.io import imread
import os

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
os.listdir("/content/drive/MyDrive/data")
# Out:
# ['without_mask', 'with_mask']

# %%
flat_data=[]
target=[]
categories=["without_mask","with_mask"]

datadir="/content/drive/MyDrive/data"
for i in categories:
  print("loding",i)
  path=os.path.join(datadir,i)

  for img in os.listdir(path):
    img_array=imread(os.path.join(path,img))
    img_resize=resize(img_array,(150,150,3))
    flat_data.append(img_resize.flatten())
    target.append(categories.index(i))
  print("loaded",i,"successfully")
# Out:
# loding without_mask
# loaded without_mask successfully
# loding with_mask
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loaded with_mask successfully

# %%
img_array
# Out:
# array([[[248, 247, 245],
#         [255, 254, 252],
#         [255, 255, 253],
#         ...,
#         [251, 255, 255],
#         [251, 255, 255],
#         [251, 255, 255]],
#
#        [[249, 255, 249],
#         [245, 255, 247],
#         [249, 255, 251],
#         ...,
#         [242, 255, 251],
#         [243, 255, 251],
#         [242, 255, 251]],
#
#        [[238, 255, 250],
#         [223, 250, 235],
#         [225, 252, 237],
#         ...,
#         [222, 255, 242],
#         [223, 255, 241],
#         [221, 255, 241]],
#
#        ...,
#
#        [[154, 152, 163],
#         [ 44,  42,  53],
#         [ 58,  52,  64],
#         ...,
#         [ 53,  38,  79],
#         [ 70,  59, 102],
#         [  5,   0,  41]],
#
#        [[191, 187, 204],
#         [ 85,  81,  98],
#         [112, 104, 125],
#         ...,
#         [ 18,   7,  41],
#         [  1,   0,  28],
#         [  2,   0,  31]],
#
#        [[182, 172, 206],
#         [ 85,  78, 111],
#         [110, 100, 135],
# ...

# %%
df=pd.DataFrame(flat_data)
df
# Out:
#          0         1         2         3         4         5         6      \
# 0     0.000000  0.003922  0.000000  0.000000  0.003922  0.000000  0.000000
# 1     0.949020  0.949020  0.949020  0.949020  0.949020  0.949020  0.949020
# 2     0.038007  0.025640  0.000921  0.056842  0.041471  0.008752  0.063490
# 3     1.000000  0.999992  0.992845  1.000000  1.000000  0.999642  0.999640
# 4     0.868524  0.868524  0.868524  0.870588  0.870588  0.870588  0.870611
# ...        ...       ...       ...       ...       ...       ...       ...
# 7548  0.992157  0.992157  0.984314  0.992157  0.992157  0.984314  0.992157
# 7549  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7550  0.929412  0.909804  0.898039  0.930491  0.910883  0.899119  0.933825
# 7551  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7552  0.941931  0.985635  0.956052  0.927839  0.979057  0.946723  0.935965
#
# ...

# %%
x=df.values
x
# Out:
# array([[0.00000000e+00, 3.92156863e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.49019608e-01, 9.49019608e-01, 9.49019608e-01, ...,
#         1.26220602e-01, 1.22299035e-01, 1.91014866e-01],
#        [3.80067974e-02, 2.56402614e-02, 9.21307190e-04, ...,
#         5.71705098e-01, 3.93299869e-01, 2.93665359e-01],
#        ...,
#        [9.29411779e-01, 9.09803936e-01, 8.98039230e-01, ...,
#         8.04353000e-01, 8.08274568e-01, 7.76902019e-01],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         9.90028453e-01, 9.93552487e-01, 9.99990168e-01],
#        [9.41931166e-01, 9.85635293e-01, 9.56051879e-01, ...,
#         7.28863034e-02, 5.50987778e-02, 1.63034443e-01]])

# %%
import numpy as np

y=np.array(target)
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.14626075446725

# %%
path="/content/images.jpeg"
a1=imread(path)
a1=resize(a1,(150,150,3))
a1=a1.flatten()
pred=model.predict([a1])
pred
# Out:
# array([1])

# %%
path="/content/download.jpeg"
a1=imread(path)
a1=resize(a1,(150,150,3))
a1=a1.flatten()
pred=model.predict([a1])
pred
# Out:
# array([0])
